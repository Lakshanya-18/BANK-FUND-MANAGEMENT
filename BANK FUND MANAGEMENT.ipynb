# %%
class RBI:
    def __init__(self):
        self.rbi_tot_acc = 100
        self.rbi_tot_fund = 50000
        super().__init__()

class SBI(RBI):
    def __init__(self):
        self.sbi_tot_acc = 50
        self.sbi_tot_fund = 25000
        super().__init__()

class TamilNadu(SBI):
    def __init__(self):
        self.tn_tot_acc = 25
        self.tn_tot_fund = 15000
        super().__init__()

class Guindy(TamilNadu):
    def __init__(self):
        self.guindy_tot_acc = 10
        self.guindy_tot_fund = 5000
        super().__init__()

    def add_new_account(self, add_account):
        if add_account != 0:
            self.rbi_tot_acc += add_account
            self.sbi_tot_acc += add_account
            self.tn_tot_acc += add_account
            self.guindy_tot_acc += add_account
            print(add_account, "- NUMBER OF NEW ACCOUNTS ADDED")
            print(self.rbi_tot_acc, "- RBI TOTAL ACCOUNTS")
            print(self.sbi_tot_acc, "- SBI TOTAL ACCOUNTS")
            print(self.tn_tot_acc, "- TAMILNADU TOTAL ACCOUNTS")
            print(self.guindy_tot_acc, "- GUINDY TOTAL ACCOUNTS\n")

    def remove_account(self, del_account):
        if del_account <= self.guindy_tot_acc:
            self.rbi_tot_acc -= del_account
            self.sbi_tot_acc -= del_account
            self.tn_tot_acc -= del_account
            self.guindy_tot_acc -= del_account
            print(del_account, "- NUMBER OF ACCOUNTS REMOVED")
            print(self.rbi_tot_acc, "- RBI TOTAL ACCOUNTS")
            print(self.sbi_tot_acc, "- SBI TOTAL ACCOUNTS")
            print(self.tn_tot_acc, "- TAMILNADU TOTAL ACCOUNTS")
            print(self.guindy_tot_acc, "- GUINDY TOTAL ACCOUNTS\n")
        else:
            print("Error")
class RBI:
    def __init__(self):
        self.rbi_tot_acc = 100
        self.rbi_tot_fund = 50000
        super().__init__()

class SBI(RBI):
    def __init__(self):
        self.sbi_tot_acc = 50
        self.sbi_tot_fund = 25000
        super().__init__()

class TamilNadu(SBI):
    def __init__(self):
        self.tn_tot_acc = 25
        self.tn_tot_fund = 15000
        super().__init__()

class Guindy(TamilNadu):
    def __init__(self):
        self.guindy_tot_acc = 10
        self.guindy_tot_fund = 5000
        super().__init__()

    def add_new_account(self, add_account):
        if add_account != 0:
            self.rbi_tot_acc += add_account
            self.sbi_tot_acc += add_account
            self.tn_tot_acc += add_account
            self.guindy_tot_acc += add_account
            print(add_account, "- NUMBER OF NEW ACCOUNTS ADDED")
            print(self.rbi_tot_acc, "- RBI TOTAL ACCOUNTS")
            print(self.sbi_tot_acc, "- SBI TOTAL ACCOUNTS")
            print(self.tn_tot_acc, "- TAMILNADU TOTAL ACCOUNTS")
            print(self.guindy_tot_acc, "- GUINDY TOTAL ACCOUNTS\n")

    def remove_account(self, del_account):
        if del_account <= self.guindy_tot_acc:
            self.rbi_tot_acc -= del_account
            self.sbi_tot_acc -= del_account
            self.tn_tot_acc -= del_account
            self.guindy_tot_acc -= del_account
            print(del_account, "- NUMBER OF ACCOUNTS REMOVED")
            print(self.rbi_tot_acc, "- RBI TOTAL ACCOUNTS")
            print(self.sbi_tot_acc, "- SBI TOTAL ACCOUNTS")
            print(self.tn_tot_acc, "- TAMILNADU TOTAL ACCOUNTS")
            print(self.guindy_tot_acc, "- GUINDY TOTAL ACCOUNTS\n")
        else:
            print("Error: Cannot remove more accounts than exist.")

    def deposit_money(self, deposit):
        self.rbi_tot_fund += deposit
        self.sbi_tot_fund += deposit
        self.tn_tot_fund += deposit
        self.guindy_tot_fund += deposit
        print(deposit, "rupees deposited to your account")
        print(self.rbi_tot_fund, "currently in RBI fund")
        print(self.sbi_tot_fund, "currently in SBI fund")
        print(self.tn_tot_fund, "currently in Tamil Nadu fund")
        print(self.guindy_tot_fund, "currently in Guindy fund\n")

    def withdraw_money(self, withdraw):
        if withdraw <= self.guindy_tot_fund:
            self.rbi_tot_fund -= withdraw
            self.sbi_tot_fund -= withdraw
            self.tn_tot_fund -= withdraw
            self.guindy_tot_fund -= withdraw
            print(withdraw, "rupees withdrawn from your account")
            print(self.rbi_tot_fund, "currently in RBI fund")
            print(self.sbi_tot_fund, "currently in SBI fund")
            print(self.tn_tot_fund, "currently in Tamil Nadu fund")
            print(self.guindy_tot_fund, "currently in Guindy fund\n")
        else:
            print("Error: Not enough funds to withdraw.")

# Create object and test
bank_system = Guindy()
bank_system.add_new_account(5)
bank_system.remove_account(5)
bank_system.withdraw_money(500)
bank_system.deposit_money(1500)
# Out:
# 5 - NUMBER OF NEW ACCOUNTS ADDED
# 105 - RBI TOTAL ACCOUNTS
# 55 - SBI TOTAL ACCOUNTS
# 30 - TAMILNADU TOTAL ACCOUNTS
# 15 - GUINDY TOTAL ACCOUNTS
#
# 5 - NUMBER OF ACCOUNTS REMOVED
# 100 - RBI TOTAL ACCOUNTS
# 50 - SBI TOTAL ACCOUNTS
# 25 - TAMILNADU TOTAL ACCOUNTS
# 10 - GUINDY TOTAL ACCOUNTS
#
# 500 rupees withdrawn from your account
# 49500 currently in RBI fund
# 24500 currently in SBI fund
# 14500 currently in Tamil Nadu fund
# 4500 currently in Guindy fund
#
# 1500 rupees deposited to your account
# 51000 currently in RBI fund
# 26000 currently in SBI fund
# 16000 currently in Tamil Nadu fund
# 6000 currently in Guindy fund
